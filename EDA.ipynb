# %%
# Autores: 
# Victor Sánchez - 20-70-7342
# Arquimedes Moran - 8-991-1628

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/2025.csv')

# %%
df.isnull().sum()
# Out:
# ID                   0
# DATE                 0
# ELEMENT              0
# DATA_VALUE           0
# M_FLAG        30869056
# Q_FLAG        34863258
# S_FLAG               0
# OBS_TIME      15914841
# dtype: int64

# %%
df = df.drop(columns=['M_FLAG', 'Q_FLAG', 'S_FLAG', 'OBS_TIME'])


df.isnull().sum()
# Out:
# ID            0
# DATE          0
# ELEMENT       0
# DATA_VALUE    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34908905 entries, 0 to 34908904
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ID          str
#  1   DATE        int64
#  2   ELEMENT     str
#  3   DATA_VALUE  int64
# dtypes: int64(2), str(2)
# memory usage: 1.0 GB

# %%
df.describe()
# Out:
#                DATE    DATA_VALUE
# count  3.490890e+07  3.490890e+07
# mean   2.025066e+07  7.288656e+01
# std    3.431289e+02  2.688831e+02
# min    2.025010e+07 -2.286000e+03
# 25%    2.025033e+07  0.000000e+00
# 50%    2.025063e+07  0.000000e+00
# 75%    2.025092e+07  1.030000e+02
# max    2.025123e+07  5.560000e+04
